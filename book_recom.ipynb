# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.metrics.pairwise import cosine_similarity
import pickle

# %%
dataset = pd.read_csv('Books.csv')
# Out:
# <ipython-input-2-82912fb2e535>:1: DtypeWarning: Columns (3) have mixed types. Specify dtype option on import or set low_memory=False.
#   dataset = pd.read_csv('Books.csv')

# %%
ratings = pd.read_csv('Ratings.csv')

# %%
dataset.head()
# Out:
#          ISBN  ...                                        Image-URL-L
# 0  0195153448  ...  http://images.amazon.com/images/P/0195153448.0...
# 1  0002005018  ...  http://images.amazon.com/images/P/0002005018.0...
# 2  0060973129  ...  http://images.amazon.com/images/P/0060973129.0...
# 3  0374157065  ...  http://images.amazon.com/images/P/0374157065.0...
# 4  0393045218  ...  http://images.amazon.com/images/P/0393045218.0...
#
# [5 rows x 8 columns]

# %%
ratings.head()
# Out:
#    User-ID        ISBN  Book-Rating
# 0   276725  034545104X            0
# 1   276726  0155061224            5
# 2   276727  0446520802            0
# 3   276729  052165615X            3
# 4   276729  0521795028            6

# %%
dataset.shape
# Out:
# (271360, 8)

# %%
dataset.isnull().sum()
# Out:
# ISBN                   0
# Book-Title             0
# Book-Author            2
# Year-Of-Publication    0
# Publisher              2
# Image-URL-S            0
# Image-URL-M            0
# Image-URL-L            3
# dtype: int64

# %%
ratings.isnull().sum()
# Out:
# User-ID        0
# ISBN           0
# Book-Rating    0
# dtype: int64

# %%
dataset.duplicated().sum()
# Out:
# np.int64(0)

# %%
ratings.duplicated().sum()
# Out:
# np.int64(0)

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 271360 entries, 0 to 271359
# Data columns (total 8 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   ISBN                 271360 non-null  object
#  1   Book-Title           271360 non-null  object
#  2   Book-Author          271358 non-null  object
#  3   Year-Of-Publication  271360 non-null  object
#  4   Publisher            271358 non-null  object
#  5   Image-URL-S          271360 non-null  object
#  6   Image-URL-M          271360 non-null  object
#  7   Image-URL-L          271357 non-null  object
# dtypes: object(8)
# memory usage: 16.6+ MB

# %%
ratings.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1149780 entries, 0 to 1149779
# Data columns (total 3 columns):
#  #   Column       Non-Null Count    Dtype
# ---  ------       --------------    -----
#  0   User-ID      1149780 non-null  int64
#  1   ISBN         1149780 non-null  object
#  2   Book-Rating  1149780 non-null  int64
# dtypes: int64(2), object(1)
# memory usage: 26.3+ MB

# %% [markdown]
# Meraging both rating and dataset on ISBN column

# %%
merge_df=dataset.merge(ratings,on='ISBN')

# %%
merge_df.head()
# Out:
#          ISBN           Book-Title  ... User-ID Book-Rating
# 0  0195153448  Classical Mythology  ...       2           0
# 1  0002005018         Clara Callan  ...       8           5
# 2  0002005018         Clara Callan  ...   11400           0
# 3  0002005018         Clara Callan  ...   11676           8
# 4  0002005018         Clara Callan  ...   41385           0
#
# [5 rows x 10 columns]

# %%
merge_df.shape
# Out:
# (1031136, 10)

# %%
merge_df.isnull().sum()
# Out:
# ISBN                   0
# Book-Title             0
# Book-Author            2
# Year-Of-Publication    0
# Publisher              2
# Image-URL-S            0
# Image-URL-M            0
# Image-URL-L            4
# User-ID                0
# Book-Rating            0
# dtype: int64

# %%
num_rating=merge_df.groupby(['Book-Title']).count()['Book-Rating'].reset_index()

# %%
num_rating.rename(columns={'Book-Rating':'num_ratings'},inplace=True)

# %%
num_rating
# Out:
#                                                Book-Title  num_ratings
# 0        A Light in the Storm: The Civil War Diary of ...            4
# 1                                   Always Have Popsicles            1
# 2                    Apple Magic (The Collector's series)            1
# 3        Ask Lily (Young Women of Faith: Lily Series, ...            1
# 4        Beyond IBM: Leadership Marketing and Finance ...            1
# ...                                                   ...          ...
# 241066                                      Ã?Â?lpiraten.            2
# 241067                     Ã?Â?rger mit Produkt X. Roman.            4
# 241068                                Ã?Â?sterlich leben.            1
# 241069                              Ã?Â?stlich der Berge.            3
# 241070                                  Ã?Â?thique en toc            2
#
# [241071 rows x 2 columns]

# %%
merge_df['Book-Rating'].dtype
# Out:
# dtype('int64')

# %%
avg_rating=merge_df.groupby('Book-Title')['Book-Rating'].mean().reset_index()
avg_rating.rename(columns={'Book-Rating':'avg_rating'},inplace=True)

# %%
avg_rating
# Out:
#                                                Book-Title  avg_rating
# 0        A Light in the Storm: The Civil War Diary of ...    2.250000
# 1                                   Always Have Popsicles    0.000000
# 2                    Apple Magic (The Collector's series)    0.000000
# 3        Ask Lily (Young Women of Faith: Lily Series, ...    8.000000
# 4        Beyond IBM: Leadership Marketing and Finance ...    0.000000
# ...                                                   ...         ...
# 241066                                      Ã?Â?lpiraten.    0.000000
# 241067                     Ã?Â?rger mit Produkt X. Roman.    5.250000
# 241068                                Ã?Â?sterlich leben.    7.000000
# 241069                              Ã?Â?stlich der Berge.    2.666667
# 241070                                  Ã?Â?thique en toc    4.000000
#
# [241071 rows x 2 columns]

# %%
popularity_df=num_rating.merge(avg_rating,on='Book-Title')

# %%
popularity_df
# Out:
#                                                Book-Title  ...  avg_rating
# 0        A Light in the Storm: The Civil War Diary of ...  ...    2.250000
# 1                                   Always Have Popsicles  ...    0.000000
# 2                    Apple Magic (The Collector's series)  ...    0.000000
# 3        Ask Lily (Young Women of Faith: Lily Series, ...  ...    8.000000
# 4        Beyond IBM: Leadership Marketing and Finance ...  ...    0.000000
# ...                                                   ...  ...         ...
# 241066                                      Ã?Â?lpiraten.  ...    0.000000
# 241067                     Ã?Â?rger mit Produkt X. Roman.  ...    5.250000
# 241068                                Ã?Â?sterlich leben.  ...    7.000000
# 241069                              Ã?Â?stlich der Berge.  ...    2.666667
# 241070                                  Ã?Â?thique en toc  ...    4.000000
#
# [241071 rows x 3 columns]

# %%
popularity_df=popularity_df[popularity_df['num_ratings']>250].sort_values('avg_rating',ascending=False).head(50)

# %%
popularity_df
# Out:
#                                                Book-Title  ...  avg_rating
# 80434   Harry Potter and the Prisoner of Azkaban (Book 3)  ...    5.852804
# 80422        Harry Potter and the Goblet of Fire (Book 4)  ...    5.824289
# 80441      Harry Potter and the Sorcerer's Stone (Book 1)  ...    5.737410
# 80426   Harry Potter and the Order of the Phoenix (Boo...  ...    5.501441
# 80414    Harry Potter and the Chamber of Secrets (Book 2)  ...    5.183453
# 191612  The Hobbit : The Enchanting Prelude to The Lor...  ...    5.007117
# 187377  The Fellowship of the Ring (The Lord of the Ri...  ...    4.948370
# 80445   Harry Potter and the Sorcerer's Stone (Harry P...  ...    4.895652
# 211384     The Two Towers (The Lord of the Rings, Part 2)  ...    4.880769
# 219741                              To Kill a Mockingbird  ...    4.700000
# 183573                                  The Da Vinci Code  ...    4.642539
# ...

# %%
popularity_df=popularity_df.merge(dataset,on='Book-Title').drop_duplicates('Book-Title')[['Book-Title','Book-Author','Year-Of-Publication','Publisher','Image-URL-M','num_ratings','avg_rating']]

# %%
popularity_df
# Out:
#                                             Book-Title  ... avg_rating
# 0    Harry Potter and the Prisoner of Azkaban (Book 3)  ...   5.852804
# 3         Harry Potter and the Goblet of Fire (Book 4)  ...   5.824289
# 5       Harry Potter and the Sorcerer's Stone (Book 1)  ...   5.737410
# 9    Harry Potter and the Order of the Phoenix (Boo...  ...   5.501441
# 13    Harry Potter and the Chamber of Secrets (Book 2)  ...   5.183453
# 16   The Hobbit : The Enchanting Prelude to The Lor...  ...   5.007117
# 17   The Fellowship of the Ring (The Lord of the Ri...  ...   4.948370
# 26   Harry Potter and the Sorcerer's Stone (Harry P...  ...   4.895652
# 28      The Two Towers (The Lord of the Rings, Part 2)  ...   4.880769
# 39                               To Kill a Mockingbird  ...   4.700000
# 47                                   The Da Vinci Code  ...   4.642539
# 53                  The Five People You Meet in Heaven  ...   4.551163
# ...

# %% [markdown]
# Collaborating **Recommendation**

# %%
merge_df.head()
# Out:
#          ISBN           Book-Title  ... User-ID Book-Rating
# 0  0195153448  Classical Mythology  ...       2           0
# 1  0002005018         Clara Callan  ...       8           5
# 2  0002005018         Clara Callan  ...   11400           0
# 3  0002005018         Clara Callan  ...   11676           8
# 4  0002005018         Clara Callan  ...   41385           0
#
# [5 rows x 10 columns]

# %%
x=merge_df.groupby('User-ID').count()['Book-Rating']>200
users=x[x].index

# %%
filtered_users=merge_df[merge_df['User-ID'].isin(users)]

# %%
filtered=filtered_users.groupby('Book-Title').count()['Book-Rating']>=50

# %%
filtered_books=filtered[filtered].index

# %%
filtered_books=filtered_users[filtered_users['Book-Title'].isin(filtered_books)]

# %%
filtered_books.head()
# Out:
#           ISBN              Book-Title  ... User-ID Book-Rating
# 31  0399135782  The Kitchen God's Wife  ...   11676           9
# 33  0399135782  The Kitchen God's Wife  ...   36836           0
# 34  0399135782  The Kitchen God's Wife  ...   46398           9
# 38  0399135782  The Kitchen God's Wife  ...  113270           0
# 39  0399135782  The Kitchen God's Wife  ...  113519           0
#
# [5 rows x 10 columns]

# %%
filtered_books.duplicated().sum()
# Out:
# np.int64(0)

# %%
pivot_tabling=filtered_books.pivot_table(index='Book-Title',columns='User-ID',values='Book-Rating').fillna(0)

# %%
pivot_tabling
# Out:
# User-ID                                             254     ...  278418
# Book-Title                                                  ...
# 1984                                                   9.0  ...     0.0
# 1st to Die: A Novel                                    0.0  ...     0.0
# 2nd Chance                                             0.0  ...     0.0
# 4 Blondes                                              0.0  ...     0.0
# A Bend in the Road                                     0.0  ...     0.0
# ...                                                    ...  ...     ...
# Year of Wonders                                        0.0  ...     0.0
# You Belong To Me                                       0.0  ...     0.0
# Zen and the Art of Motorcycle Maintenance: An I...     0.0  ...     0.0
# Zoya                                                   0.0  ...     0.0
# \O\" Is for Outlaw"                                    0.0  ...     0.0
#
# [706 rows x 810 columns]

# %%
similarity_score=cosine_similarity(pivot_tabling)

# %%
similarity_score[0].shape
# Out:
# (706,)

# %%
sorted(list(enumerate(similarity_score[np.where(pivot_tabling.index=='Zoya')[0][0]])),key=lambda x:x[1],reverse=True)[1:6]
# Out:
# [(194, np.float64(0.6188332046777835)),
#  (424, np.float64(0.5423917439488084)),
#  (288, np.float64(0.4536936187776783)),
#  (175, np.float64(0.43416881684252095)),
#  (196, np.float64(0.43104197190280946))]

# %%
def recommend(book_name):
    index=np.where(pivot_tabling.index==book_name)[0][0]
    distance = similarity_score[index]
    similar_item=sorted(list(enumerate(distance)),key=lambda x:x[1],reverse=True)[1:9]
    data=[]
    for i in similar_item:
       temp_store=[]
       temp=dataset[dataset['Book-Title']==pivot_tabling.index[i[0]]]
       temp_store = [
                temp['Book-Title'].values[0],
                temp['Book-Author'].values[0],
                temp['Publisher'].values[0],
                temp['Image-URL-M'].values[0]
            ]
       data.append(temp_store)
    return data

# %%
recommend('Nights in Rodanthe')
# Out:
# [['The Mulberry Tree',
#   'Jude Deveraux',
#   'Pocket',
#   'http://images.amazon.com/images/P/0743437640.01.MZZZZZZZ.jpg'],
#  ['Dark Angel',
#   'V.C. Andrews',
#   'Pocket',
#   'http://images.amazon.com/images/P/0671525433.01.MZZZZZZZ.jpg'],
#  ['A Walk to Remember',
#   'Nicholas Sparks',
#   'Warner Books',
#   'http://images.amazon.com/images/P/0446608955.01.MZZZZZZZ.jpg'],
#  ['GARDEN OF SHADOWS (Dollanger Saga (Paperback))',
#   'Ariel Jennifer Jones',
#   'Pocket',
#   'http://images.amazon.com/images/P/067164257X.01.MZZZZZZZ.jpg'],
#  ['The Wedding',
#   'Nicholas Sparks',
#   'Warner Books',
#   'http://images.amazon.com/images/P/0446532452.01.MZZZZZZZ.jpg'],
#  ['Whispers',
#   'BELVA PLAIN',
#   'Dell',
#   'http://images.amazon.com/images/P/0440216745.01.MZZZZZZZ.jpg'],
#  ['Sea Glass: A Novel',
#   'Anita Shreve',
#   'Back Bay Books',
#   'http://images.amazon.com/images/P/0316089699.01.MZZZZZZZ.jpg'],
#  ['Message in a Bottle',
#   'Nicholas Sparks',
# ...

# %%
pickle.dump(popularity_df,open('popular.pkl','wb'))

# %%
pickle.dump(pivot_tabling,open('pivot_tabling.pkl','wb'))
pickle.dump(dataset,open('books.pkl','wb'))
pickle.dump(similarity_score,open('similarity_score.pkl','wb'))
